# %%
import pandas as pd
import numpy as np
df=pd.read_csv('/content/satyaml.csv')

# %%
df.head()
# Out:
#    Chiral indice n  Chiral indice m  Initial atomic coordinate u  \
# 0                2                1                       679005
# 1                2                1                       717298
# 2                2                1                       489336
# 3                2                1                       413957
# 4                2                1                       334292
#
#    Initial atomic coordinate v  Initial atomic coordinate w  \
# 0                       701318                        17033
# 1                       642129                       231319
# 2                       303751                        88462
# 3                       632996                        40843
# 4                       543401                        15989
#
#    Calculated atomic coordinates u'  Calculated atomic coordinates v'  \
# 0                            721039                            730232
# 1                            738414                             65675
# 2                            477676                            263221
# 3                            408823                            657897
# 4                            303349                            558807
#
#    Calculated atomic coordinates w'
# 0                             17014
# 1                            232369
# 2                             88712
# 3                             39796
# 4                            157373

# %%
x=df.drop("Calculated atomic coordinates w'",axis=1)

# %%
y=df["Calculated atomic coordinates w'"]

# %%
x.head()
# Out:
#    Chiral indice n  Chiral indice m  Initial atomic coordinate u  \
# 0                2                1                       679005
# 1                2                1                       717298
# 2                2                1                       489336
# 3                2                1                       413957
# 4                2                1                       334292
#
#    Initial atomic coordinate v  Initial atomic coordinate w  \
# 0                       701318                        17033
# 1                       642129                       231319
# 2                       303751                        88462
# 3                       632996                        40843
# 4                       543401                        15989
#
#    Calculated atomic coordinates u'  Calculated atomic coordinates v'
# 0                            721039                            730232
# 1                            738414                             65675
# 2                            477676                            263221
# 3                            408823                            657897
# 4                            303349                            558807

# %%
from sklearn.model_selection import train_test_split

# %%
xtr,xts,ytr,yts=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
xtr = scaler.fit_transform(xtr)
xts = scaler.transform(xts)

# %%
from sklearn.linear_model import LogisticRegression

# Create a logistic regression model
logreg = LogisticRegression()

# Fit the model to the training data
logreg.fit(xtr, ytr)

# Make predictions on the testing data
y_pred = logreg.predict(xts)

# %%
# Evaluate the model performance
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
yts=yts.to_numpy().reshape(-1,1)
# accuracy = logreg.score(yts, y_pred)
# precision = precision_score(yts, y_pred)
# recall = recall_score(yts, y_pred)
# f1 = f1_score(yts, y_pred)

# print("Accuracy:", accuracy)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-78e4ab50242a> in <cell line: 3>()
#       1 # Evaluate the model performance
#       2 from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
# ----> 3 yts=yts.to_numpy().reshape(-1,1)
#       4 # accuracy = logreg.score(yts, y_pred)
#       5 # precision = precision_score(yts, y_pred)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'to_numpy'
